# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q scipy
# !pip install -q h5py
# !pip install -q matplotlib
# !pip install -q torch torchvision torchaudio
# !pip install -q transformers
# !pip install -q fuzzy_match
# !pip install -q nltk
# !pip install -q rouge
# !pip install -q diffusers
# !pip install -q tensorboard
# !pip install -q tqdm
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 26.1 MB/s eta 0:00:00

# %%
# %cd /content/drive/MyDrive/Research/FINAL/Code/MMMM
# Out:
# /content/drive/MyDrive/Research/FINAL/Code/MMMM

# %%
import pickle

# %%
import os

HYPERPARAM_CKPT_PATH = f"./tuning/EEG-TEXT-BART/TUNING_PROGRESS_CKPT.pkl"
completed = []
if os.path.exists(HYPERPARAM_CKPT_PATH):
    with open(HYPERPARAM_CKPT_PATH, "rb") as f:
        completed = pickle.load(f)
print(completed)
# Out:
# ['Adam-128-0.005', 'AdamW-128-0.005', 'SGD-128-0.005', 'Adagrad-128-0.005', 'RMSprop-128-0.005', 'Adam-128-0.001', 'AdamW-128-0.001', 'SGD-128-0.001', 'Adagrad-128-0.001', 'RMSprop-128-0.001', 'Adam-128-0.0005', 'AdamW-128-0.0005', 'SGD-128-0.0005', 'Adagrad-128-0.0005', 'RMSprop-128-0.0005', 'Adam-128-0.0001', 'AdamW-128-0.0001', 'SGD-128-0.001', 'Adam-128-0.0001', 'AdamW-128-0.0001', 'SGD-128-0.0001', 'Adagrad-128-0.0001', 'RMSprop-128-0.0001', 'Adam-128-5e-05']

# %%
# !python3 ./tuning/EEG-TEXT-BART/tune_EEG-TEXT-BART.py
# Out:
# 2023-11-25 10:21:48.054190: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-25 10:21:48.054238: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-25 10:21:48.054264: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-25 10:21:49.153706: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [INFO] Initialized hyperparameter choices for tuning.
# ['Adam-128-0.005', 'AdamW-128-0.005', 'SGD-128-0.005', 'Adagrad-128-0.005', 'RMSprop-128-0.005', 'Adam-128-0.001', 'AdamW-128-0.001', 'SGD-128-0.001', 'Adagrad-128-0.001', 'RMSprop-128-0.001', 'Adam-128-0.0005', 'AdamW-128-0.0005', 'SGD-128-0.0005', 'Adagrad-128-0.0005', 'RMSprop-128-0.0005', 'Adam-128-0.0001', 'AdamW-128-0.0001', 'SGD-128-0.001', 'Adam-128-0.0001', 'AdamW-128-0.0001', 'SGD-128-0.0001', 'Adagrad-128-0.0001', 'RMSprop-128-0.0001', 'Adam-128-5e-05']
# tokenizer_config.json: 100% 26.0/26.0 [00:00<00:00, 132kB/s]
# vocab.json: 100% 899k/899k [00:00<00:00, 3.62MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 18.2MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 5.69MB/s]
# config.json: 100% 1.63k/1.63k [00:00<00:00, 8.63MB/s]
# [INFO] Loaded tokenizer.
# [INFO] Manual seed set to 1066.
# [INFO] Configured BASE model.
# [INFO] Intialized dataloaders.
# 0it [00:00, ?it/s]
# [INFO] Adam-128-0.005 already complete.
#
# [INFO] AdamW-128-0.005 already complete.
#
# [INFO] SGD-128-0.005 already complete.
#
# [INFO] Adagrad-128-0.005 already complete.
#
# [INFO] RMSprop-128-0.005 already complete.
#
# [INFO] Adam-128-0.001 already complete.
#
# [INFO] AdamW-128-0.001 already complete.
#
# [INFO] SGD-128-0.001 already complete.
#
# [INFO] Adagrad-128-0.001 already complete.
#
# [INFO] RMSprop-128-0.001 already complete.
#
# [INFO] Adam-128-0.0005 already complete.
#
# [INFO] AdamW-128-0.0005 already complete.
#
# [INFO] SGD-128-0.0005 already complete.
#
# [INFO] Adagrad-128-0.0005 already complete.
#
# [INFO] RMSprop-128-0.0005 already complete.
#
# [INFO] Adam-128-0.0001 already complete.
#
# [INFO] AdamW-128-0.0001 already complete.
#
# [INFO] SGD-128-0.0001 already complete.
#
# [INFO] Adagrad-128-0.0001 already complete.
#
# [INFO] RMSprop-128-0.0001 already complete.
#
# [INFO] Adam-128-5e-05 already complete.
#
# [INFO] Setting up AdamW-128-5e-05...
#
# pytorch_model.bin:   0% 0.00/1.02G [00:00<?, ?B/s]
# pytorch_model.bin:   2% 21.0M/1.02G [00:00<00:05, 189MB/s]
# pytorch_model.bin:   7% 73.4M/1.02G [00:00<00:02, 364MB/s]
# pytorch_model.bin:  12% 126M/1.02G [00:00<00:02, 388MB/s]
# pytorch_model.bin:  16% 168M/1.02G [00:00<00:02, 339MB/s]
# pytorch_model.bin:  22% 220M/1.02G [00:00<00:02, 386MB/s]
# pytorch_model.bin:  26% 262M/1.02G [00:00<00:02, 350MB/s]
# pytorch_model.bin:  30% 304M/1.02G [00:00<00:02, 351MB/s]
# pytorch_model.bin:  34% 346M/1.02G [00:00<00:01, 356MB/s]
# pytorch_model.bin:  38% 388M/1.02G [00:01<00:01, 365MB/s]
# pytorch_model.bin:  42% 430M/1.02G [00:01<00:01, 367MB/s]
# pytorch_model.bin:  46% 472M/1.02G [00:01<00:01, 367MB/s]
# pytorch_model.bin:  50% 514M/1.02G [00:01<00:01, 372MB/s]
# pytorch_model.bin:  55% 556M/1.02G [00:01<00:01, 354MB/s]
# pytorch_model.bin:  59% 598M/1.02G [00:01<00:01, 339MB/s]
# pytorch_model.bin:  63% 640M/1.02G [00:01<00:01, 340MB/s]
# pytorch_model.bin:  67% 682M/1.02G [00:01<00:00, 340MB/s]
# pytorch_model.bin:  71% 724M/1.02G [00:02<00:00, 333MB/s]
# pytorch_model.bin:  75% 765M/1.02G [00:02<00:00, 336MB/s]
# pytorch_model.bin:  79% 807M/1.02G [00:02<00:00, 349MB/s]
# pytorch_model.bin:  84% 860M/1.02G [00:02<00:00, 367MB/s]
# pytorch_model.bin:  89% 902M/1.02G [00:02<00:00, 366MB/s]
# pytorch_model.bin:  93% 944M/1.02G [00:02<00:00, 373MB/s]
# pytorch_model.bin: 100% 1.02G/1.02G [00:02<00:00, 356MB/s]
# [INFO] Set up complete.
# [INFO] Beginning training for AdamW-128-5e-05.
# |Epoch Num     |Task Name     |Current Loss            |Test Loss                 |Status            |Time                    |
# |           0|EEG-TEXT-BART|       6.479973546|       5.339121111|TRAINING        |      191.19 s|
# |           1|EEG-TEXT-BART|       5.972347876|       4.998274963|TRAINING        |      190.28 s|
# |           2|EEG-TEXT-BART|       7.292110344|       4.814395286|TRAINING        |      189.61 s|
# |           3|EEG-TEXT-BART|       6.565058894|       4.752916972|TRAINING        |      189.74 s|
# |           4|EEG-TEXT-BART|       6.333099476|       4.703337829|TRAINING        |      189.73 s|
# |           5|EEG-TEXT-BART|       6.080099996|       4.678651817|TRAINING        |      189.65 s|
# |           6|EEG-TEXT-BART|       5.973480399|       4.679804630|TRAINING        |      189.69 s|
# |           7|EEG-TEXT-BART|       5.692449645|       4.672189479|TRAINING        |      189.36 s|
# |           8|EEG-TEXT-BART|       5.455118767|       4.665645905|TRAINING        |      189.66 s|
# |           9|EEG-TEXT-BART|       5.364509897|       4.664600722|TRAINING        |      189.82 s|
# 22it [33:12, 90.56s/it]
# [INFO] Setting up SGD-128-5e-05...
# [INFO] Set up complete.
# [INFO] Beginning training for SGD-128-5e-05.
# |Epoch Num     |Task Name     |Current Loss            |Test Loss                 |Status            |Time                    |
# |           0|EEG-TEXT-BART|       6.515145168|       5.043051112|TRAINING        |      188.97 s|
# |           1|EEG-TEXT-BART|       6.146367317|       5.039374071|TRAINING        |      188.82 s|
# |           2|EEG-TEXT-BART|       6.069394996|       5.042888434|TRAINING        |      188.39 s|
# |           3|EEG-TEXT-BART|       6.068643611|       5.036967767|TRAINING        |      188.42 s|
# |           4|EEG-TEXT-BART|       6.053921944|       5.029472724|TRAINING        |      188.74 s|
# |           5|EEG-TEXT-BART|       6.034831826|       5.027537747|TRAINING        |      190.01 s|
# |           6|EEG-TEXT-BART|       6.027268724|       5.022913877|TRAINING        |      188.62 s|
# |           7|EEG-TEXT-BART|       6.032182234|       5.014519528|TRAINING        |      189.25 s|
# |           8|EEG-TEXT-BART|       5.966683585|       5.006787719|TRAINING        |      188.78 s|
# |           9|EEG-TEXT-BART|       5.939136842|       4.834272037|TRAINING        |      188.91 s|
# 23it [1:05:55, 204.76s/it]
# [INFO] Setting up Adagrad-128-5e-05...
# [INFO] Set up complete.
# [INFO] Beginning training for Adagrad-128-5e-05.
# |Epoch Num     |Task Name     |Current Loss            |Test Loss                 |Status            |Time                    |
# |           0|EEG-TEXT-BART|       6.213431283|       5.528094025|TRAINING        |      189.68 s|
# |           1|EEG-TEXT-BART|       6.562162818|       6.288418501|TRAINING        |      189.42 s|
# |           2|EEG-TEXT-BART|       6.649260306|       6.013728272|TRAINING        |      189.59 s|
# |           3|EEG-TEXT-BART|       6.566689381|       5.831592532|TRAINING        |      189.14 s|
# |           4|EEG-TEXT-BART|       6.458654206|       5.260854874|TRAINING        |      189.67 s|
# |           5|EEG-TEXT-BART|       6.515386994|       5.976858455|TRAINING        |      189.12 s|
# |           6|EEG-TEXT-BART|       6.411888733|       5.815119279|TRAINING        |      189.33 s|
# |           7|EEG-TEXT-BART|       6.440661407|       5.504393974|TRAINING        |      189.22 s|
# |           8|EEG-TEXT-BART|       6.278551706|       5.863395840|TRAINING        |      189.48 s|
# |           9|EEG-TEXT-BART|       6.304463288|       5.376358393|TRAINING        |      188.89 s|
# 24it [1:37:55, 342.15s/it]
# [INFO] Setting up RMSprop-128-5e-05...
# [INFO] Set up complete.
# [INFO] Beginning training for RMSprop-128-5e-05.
# |Epoch Num     |Task Name     |Current Loss            |Test Loss                 |Status            |Time                    |
# |           0|EEG-TEXT-BART|       7.496150691|       5.907347540|TRAINING        |      189.64 s|
# |           1|EEG-TEXT-BART|       5.972124170|       4.700919784|TRAINING        |      189.98 s|
# |           2|EEG-TEXT-BART|       5.418183571|       4.637844290|TRAINING        |      189.79 s|
# |           3|EEG-TEXT-BART|       5.034289383|       4.631704030|TRAINING        |      190.04 s|
# |           4|EEG-TEXT-BART|       4.916850230|       4.941079327|TRAINING        |      190.78 s|
# |           5|EEG-TEXT-BART|       5.186686336|       4.985458001|TRAINING        |      189.64 s|
# |           6|EEG-TEXT-BART|       4.650778910|       4.783644097|TRAINING        |      190.00 s|
# |           7|EEG-TEXT-BART|       4.503050708|       4.926751582|TRAINING        |      190.53 s|
# |           8|EEG-TEXT-BART|       4.323281407|       4.842105212|TRAINING        |      190.21 s|
# |           9|EEG-TEXT-BART|       4.114372143|       4.774376811|TRAINING        |      190.56 s|
# 25it [2:10:11, 312.45s/it]
