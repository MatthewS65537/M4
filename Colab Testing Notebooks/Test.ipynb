# %%
# %cd /home/qid/MMMM
# Out:
# /home/qid/MMMM

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /home/qid/snap/jupyter/common/lib/python3.7/site-packages (1.13.1)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66; platform_system == "Linux" in /home/qid/snap/jupyter/common/lib/python3.7/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: typing-extensions in /home/qid/snap/jupyter/common/lib/python3.7/site-packages (from torch) (4.7.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99; platform_system == "Linux" in /home/qid/snap/jupyter/common/lib/python3.7/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96; platform_system == "Linux" in /home/qid/snap/jupyter/common/lib/python3.7/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99; platform_system == "Linux" in /home/qid/snap/jupyter/common/lib/python3.7/site-packages (from torch) (11.7.99)
# Requirement already satisfied: wheel in /snap/jupyter/6/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66; platform_system == "Linux"->torch) (0.33.4)
# Requirement already satisfied: setuptools in /snap/jupyter/6/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66; platform_system == "Linux"->torch) (41.0.1)

# %%
# !pip freeze
# Out:
# nvidia-cublas-cu11==11.10.3.66
# nvidia-cuda-nvrtc-cu11==11.7.99
# nvidia-cuda-runtime-cu11==11.7.99
# nvidia-cudnn-cu11==8.5.0.96
# torch==1.13.1
# typing-extensions==4.7.1

# %%
import torch
from torch.utils.data import DataLoader

class ImageNetDataloader():
	def __init__(self, labeled_eeg, image_net_dict, bsz=64, drop_last = True):
		super(ImageNetDataloader, self).__init__()
		self.labeled_eeg = labeled_eeg
		self.image_net_dict = image_net_dict
		self.bsz = bsz
		self.ptr = 0
		self.dataset_size = len(labeled_eeg["labels"])
		self.drop_last = drop_last
		self.reset = False

	def load_data():
		self.ptr += bsz
		if (self.ptr > (dataset_size // bsz * bsz) and drop_last) or (self.ptr > dataset_size and not drop_last):
			self.reset = True
		target = [img_dict[labeled_eeg["labels"][i]] for i in range(ptr - 64, min(ptr, dataset_size))]
		sz = min(ptr, dataset_size) - (ptr - 64)
		return {"data" : self.labeled_eeg["eeg"][ptr-bsz:min(ptr, dataset_size)], "target" : target, "size" : sz}

	def reset():
		if self.reset:
			self.reset = False
			self.ptr = 0
			return True
		return False



class ZuCoDataloader():
	def __init__(self, data, targets, bsz=64, drop_last = True):
		super(ImageNetDataloader, self).__init__()
		self.eeg_dataloader = DataLoader(data, batch_size=bsz, shuffle=False, drop_last=drop_last)
		self.embeds_dataloader = DataLoader(targets, batch_size=bsz, shuffle=False, drop_last=drop_last)
		self.eeg_iter = iter(eeg_dataloader)
		self.embeds_iter = iter(embeds_dataloader)
		self.reset = False

	def load_data():
		try:
			eeg = next(eeg_iter)
			embed = next(embeds_iter)[:,0,:,:]

			return {"data" : eeg, "target" : embed, "size" : embed.shape[0]}
		except StopIteration:
			self.reset()
			self.load_data()


	def reset():
		self.eeg_iter = iter(eeg_dataloader)
		self.embeds_iter = iter(embeds_dataloader)

# %%
import pickle
import torch

def load_txt_data(dir="./data"):
	with open(f"{dir}/ZuCoProcessedDatasetDict.pkl", "rb") as f:
		master_eeg = pickle.load(f)
	with open(f"{dir}/ZuCoTargetStringsEmbeds.pkl", "rb") as f:
		master_embeds = pickle.load(f)
	return (master_eeg, master_embeds)

def load_img_data(dir="./data"):
	with open(f"{dir}/imageNet_labeled_eeg.pkl", "rb") as f:
		image_eeg_labels = pickle.load(f)
	with open(f"{dir}/image_net_dict.pkl", "rb") as f:
		img_net_dict = pickle.load(f)
	return (labeled_eeg, image_net_dict)

# %%
master_eeg, master_embeds = load_txt_data()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-eb4e7c6f1e27> in <module>
# ----> 1 master_eeg, master_embeds = load_txt_data()
#
# <ipython-input-13-20b497fb0137> in load_txt_data(dir)
#       4 def load_txt_data(dir="./data"):
#       5         with open(f"{dir}/ZuCoProcessedDatasetDict.pkl", "rb") as f:
# ----> 6                 master_eeg = pickle.load(f)
#       7         with open(f"{dir}/ZuCoTargetStringsEmbeds.pkl", "rb") as f:
#       8                 master_embeds = pickle.load(f)
#
# AttributeError: Can't get attribute 'ZuCo_dataset' on <module 'data' (namespace)>
