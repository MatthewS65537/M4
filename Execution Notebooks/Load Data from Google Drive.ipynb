# %%
# %cd /home/qid/MMMM
# Out:
# /home/qid/MMMM

# %%
# !pwd
# Out:
# /home/qid/MMMM

# %%
# !ls
# Out:
# 'Colab Testing Notebooks'   README.md   models	  push.sh    utils
# 'Execution Notebooks'	    data        pull.sh   training

# %%
# %cd /home/qid/MMMM/data
# Out:
# /home/qid/MMMM/data

# %%
# ZuCoTargetStringsEmbeds.pkl
wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1-9iTRFgb9iqcno31TejhJeZBi3lJjDOg' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1-9iTRFgb9iqcno31TejhJeZBi3lJjDOg" -O ZuCoTargetStringsEmbeds.pkl && rm -rf /tmp/cookies.txt
# ZuCoProcessedDatasetDict.pkl
wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=18KXVFS-VnuySdsEimx-I1kSbTPALxx_j' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=18KXVFS-VnuySdsEimx-I1kSbTPALxx_j" -O ZuCoProcessedDatasetDict.pkl && rm -rf /tmp/cookies.txt

wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1-IdtXybDM3kACUjHBFhHpKvPwThIh4eh' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1-IdtXybDM3kACUjHBFhHpKvPwThIh4eh" -O image_net_dict.pkl && rm -rf /tmp/cookies.txt
